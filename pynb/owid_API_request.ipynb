# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/annual-co2-emissions-per-country.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})
df.head()
# Out:
#         Entity Code  Year  emissions_total
# 0  Afghanistan  AFG  1949         14656.00
# 1  Afghanistan  AFG  1950         84272.00
# 2  Afghanistan  AFG  1951         91600.00
# 3  Afghanistan  AFG  1952         91600.00
# 4  Afghanistan  AFG  1953        106256.00

# %%
# Find the most recent year
most_recent_year = df["Year"].max()

# Filter the DataFrame to only include rows from the most recent year
df = df[df["Year"] == most_recent_year]
# Set pandas to display numbers in standard notation
pd.options.display.float_format = '{:.2f}'.format

df.head()
# Out:
#            Entity Code  Year  emissions_total
# 74    Afghanistan  AFG  2023      11020218.00
# 214        Africa  NaN  2023    1418739200.00
# 388  Africa (GCP)  NaN  2023    1418728100.00
# 479       Albania  ALB  2023       5144279.00
# 587       Algeria  DZA  2023     178132770.00

# %%
df = df.dropna(subset=["Code"])
df = df.drop(columns = ["Code"])
df = df[df["Entity"] != "World"]

# %%
df = df.nlargest(10, "emissions_total")
df["emissions_total"] = df["emissions_total"] / 100000000
df.head(11)
# Out:
#               Entity  Year  emissions_total
# 5723           China  2023            11.90
# 27697  United States  2023             4.91
# 12923          India  2023             3.06
# 22341         Russia  2023             1.82
# 14018          Japan  2023             0.99
# 13320           Iran  2023             0.82
# 23028   Saudi Arabia  2023             0.74
# 13058      Indonesia  2023             0.73
# 11088        Germany  2023             0.60
# 24585    South Korea  2023             0.58

# %%
plt.bar(df["Entity"],df["emissions_total"])
# Rotate x-axis labels
plt.xticks(rotation=45)  # Rotates labels by 45 degrees
plt.ticklabel_format(style="plain", axis="y")
# Labels and Title
plt.xlabel("Country")
plt.ylabel("Total Emissions (billions)")
plt.title("Total Emissions by Country")
plt.show()

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/annual-co2-emissions-per-country.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Find the most recent year
most_recent_year = df["Year"].max()

# Filter the DataFrame to only include rows from the most recent year
df = df[df["Year"] == most_recent_year]
# Set pandas to display numbers in standard notation
pd.options.display.float_format = '{:.2f}'.format

# Clean data 

df = df.dropna(subset=["Code"])
df = df.drop(columns = ["Code"])
df = df[df["Entity"] != "World"]

df = df.nlargest(10, "emissions_total")
df["emissions_total"] = df["emissions_total"] / 100000000


plt.bar(df["Entity"],df["emissions_total"])
# Rotate x-axis labels
plt.xticks(rotation=45)  # Rotates labels by 45 degrees
plt.ticklabel_format(style="plain", axis="y")
# Labels and Title
plt.xlabel("Country")
plt.ylabel("Total Emissions (billions)")
plt.title("Total Emissions by Country")
plt.show()
